# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [2,4,1]

# %%
# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
  
# giving a title to my graph 
plt.title('My first graph!') 
  
# function to show the plot 
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import random

def fun(x, y):
    return x**3 + y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
n = 10
xs = [i for i in range(-1*n, n) for _ in range(-1*n, n)]
ys = list(range(n)) * n
zs = [fun(x, y) for x,y in zip(xs,ys)]

ax.scatter(xs, ys, zs)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-4c6a21330fad> in <module>()
#      14 zs = [fun(x, y) for x,y in zip(xs,ys)]
#      15
# ---> 16 ax.scatter(xs, ys, zs)
#      17
#      18 ax.set_xlabel('X Label')
#
# /home/folen/.local/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2301
#    2302         xs, ys, zs = np.broadcast_arrays(
# -> 2303             *[np.ravel(np.ma.filled(t, np.nan)) for t in [xs, ys, zs]])
#    2304         s = np.ma.ravel(s)  # This doesn't have to match x, y in size.
#    2305
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# /home/folen/.local/lib/python3.6/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     256     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     257
# --> 258     shape = _broadcast_shape(*args)
#     259
#     260     if all(array.shape == shape for array in args):
#
# /home/folen/.local/lib/python3.6/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     187     # use the old-iterator because np.nditer does not handle size 0 arrays
#     188     # consistently
# --> 189     b = np.broadcast(*args[:32])
#     190     # unfortunately, it cannot handle 32 or more arguments directly
#     191     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
